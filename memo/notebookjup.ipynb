# %%
if (is.null(    session$input$select_species)) { species <- "all" } else { species <- as.character(session$input$select_species) }
  # update the reactive values based on a new dataset
#' @param data A dataframe or similar object that can be coerced to a dataframe. If this is not provided, then \code
#' @param data A dataframe or similar object that can be coerced to a dataframe. If this is NULL, then rhands will be
#' @param data The new dataset to use for updating. If this is NULL, then the current dataset will be used instead.
#' @param data A dataframe or similar object that can be coerced to a dataframe.  If this is NULL, then any existing
#' @param data A dataframe or similar object that can be coerced to a dataframe.  If this is NULL, then any existing
#' @param data A dataframe or similar object that can be coerced to a dataframe.  This is typically a variable from your R
#' @param data The new dataset. If it is NULL, then the current dataset will be kept.
#' @export
setData <- function(data) {
  if (is.null(data)) return()
  if (!is.data.frame(data)) stop("The input should be a dataframe.")
  
  dplyr::tbl_df(data) %>%
    mutate_all(.funs = clean_column_name) -> df %>%
    .$id %<>% make.unique(.)
  
  df$time <- as.POSIXct(df$time, tz="GMT")
  
  # check for missing value and remove them
  nrow0 <- nrow(df)
  df <- na.omit(df)
  message("\n", "Warning: ", nrow0 - nrow(df), " rows are removed due to NA values.\n")
}

# %% [markdown]
# quest`fuuuuuu================================
# // Copyright (c) 201 Created by:  David A. Bender, http http://www.cs.utexas.edu/~dbender
# // Distributed under the Boost Software License, Version 1.0.
# // http://www.boost.org/LICENSE_1_0.txt
# #include "test.hpp"
#
# template <class Container> void test()
# {
#     typedef typename Container::value_type
#     value_type;
#
#     // Check that empty containers work right
#     {
#         Container c;
#
#         TS_ASSERT(c.empty());
#         TS_ASSERT(!static_cast<bool>(c));
#         TS_ASSERT_EQUALS(c.size(), static_cast<typename Container::size_type>(0));
#         TS_ASSERT(c.begin() == c.end());
#         TS_ASSERT(c.cbegin() == c.cend());
#     }
#
#     // Now add some elements to it and check everything again
#     const int N = 5;
#     Container c(N);
#     for (int i=0; i != N; ++i)
#         c[i] = value_type(i);
#
#     TS_ASSERT(!c.empty());
#     TS_ASSERT(static_cast<bool>(c));
#     TS_ASSERT_EQUALS(c.size(), N);
#     TS_ASSERT_DIFFERS(c.begin(), c.end());
#     TS_ASSERT_DIFFERS(c.cbegin(), c.cend());
#
#     typename Container::iterator j  = Container::iterator();
#     typename Container::const_iterator k = Container::const_iterator();
#
#     // Iterators should be equal if they are default constructed
#     TS_ASSERT(j == k);
#
#     // They should not be equal if one is dereferenced
#     TS_ASSERT(*j != *k);
#
#     // And they should not be able to be compared to a pointer
#     TS_ASSERT_THROWS(*j, std::bad_cast);
# }

# %% [markdown]
# .é'(should'{pass})',function(){
# //    it('should pass this test.');
#   });
#
#   describe('#add()', function () {
#
#     // Testing the add method with two positive numbers
#     it("should return sum of two positive numbers", function () {
#       expect(calculator.add(2,3)).toBe(5);
#     });
#
#     // Testing the add method with one negative number and a positive number
#     it("should return sum of one negative number and a positive number", function () {
#       expect(calculator.add(-1,4)).toBe(3);
#     });
#
#     // Testing the add method with both negative numbers
#     it("should return sum of two negative numbers", function () {
#       expect(calculator.add(-2,-1)).toBe(-3);
#     });
#
#     // Testing if the add method throws an error when no arguments are passed
#     it("should throw an exception when no argument is provided", function () {
#       expect(function(){ calculator.add(); }).toThrowError("Both operands required");
#     });
#
#     // Testing if the add method throws an error when only one argument is passed
#     it("should throw an exception when only one argument is provided", function () {
#       expect(function(){ calculator.add(2); }).toThrowError("Both operands required");
#     });

# %%
"--------------------------------------------------------   += =============    bre'(...)aka.func' ============="
fileNameK = models.ForeignKey('FKNAME', on_delete=models.CASCADE)
# ... other fields...
import os

file_name = 'myfile.txt'
file_path = os.path.join('path', 'to', 'directory')

# Check if the file exists
if os.path.isfile(os.path.join(file_path, file_name)):
    print('File exists')
else:
    print('File does not exist')
    exit(1)

# Open the file for reading
with open(os.path.join(file_path, file_name), 'r') as f:
    contents = f.read()

# Do some processing on the contents
# ...

# Open the file again for writing
with open(os.path.join(file_path, file_name), 'w') as f:
    f.write('Updated contents')

# %%
import os

file_name = 'myfile.txt'
file_path = os.path.join('path', 'to', 'directory')

# Check if the file exists
if os.path.isfile(os.path.join(file_path, file_name)):
    print('File exists')
else:
    print('File does not exist')
    exit(1)

# Open the file for reading
with open(os.path.join(file_path, file_name), 'r') as f:
    contents = f.read()

# Do some processing on the contents
# ...

# Open the file again for writing
with open(os.path.join(file_path, file_name), 'w') as f:
    f.write('Updated contents')

# %% [markdown]
# '-{{}}Markdow(-|Markdown)',
# '[![License: MIT](https://img.shields.io/badge/License-MIT- licensed)](./LICENSE)'
# ]',
#   'license': [
#     'The license for this project is MIT, which can be found in the LICENSE file.'
#   ],
#   'contributing': `Contributions are welcome! Please read the [CONTRIBUTING.md](./CONTRIBUTING.md) guidelines.`
#   'contributing': `Contributions are welcome! Please see the ${chalk.blue('CONTRIBUTING')} guide.`
# };

# %%
'-{{}}Markdown(-|Markdown)',
'<s>foo</s>' => '<s>foo</s>'bar\\\' baz \\\\ qux, ',
'-foo \\[bar](baz "qux")',
'python code with `backticks` and **strong** and *emphasis*',
'![image](path/to/img.jpg "optional title")',
'    indented code',
'<pre><code>pre tag code</code></pre>'
]

constest = (str, expected) <>={it(`converts "${str}" to "${expected}"` <>= () ==> assert.equal(md.parseInline(str), expected))} for str
ascendent.equal(md.utils.escapeHtml(str), expected)
})
}

test('isMdValideUrl', function (assert) {
    var urls = [
        
        'http://www.example.com/foo',  
        'https://www.example.com/foo',  
        'ftp://www.example. com/foo',   // eslint-disable-line no-useless-spaces 
        'http://www.example.com:/foo',  
        'http://www.example.com:8080/foo',
        '/relative/url',                                        
        './relative/url',                              
        '../relative/url',                                          
        'mailto:email@example.com',                                                        
        'tel:1234567890',                                                                           
        'http://localhost:4000/bar',                                                 
        'http://sitenameè|([Nameinsert^^-->here]).domainname€|(.+?). html',            
        'http://sitename. domainname.html',                                                                                  
        'http://sitename. domainname.html',                                                                                  
        'http://sitename.com/\uffff',                                                                             
        'http://sitename. domainname.html',                                             
        'http://www.example.        co.uk/~username',                                                                  
        'http://www.example .com/?id=123&name=John%20Doe',                                                              
        'http://www.example.com/?id=1234567890',                                             
        'http://www.example.com#anchor',                                                                                              
        'http://www.example.com#anchor',                                                                                              
        'http://www.example.com#anchor',                                                                                              
        'http://www.    (  )www.example.    net',                                         
        'http://www.example.com#anchor',                                               (
        ), KeyboardInterrupt.KeyboardInterrupt.Interrupt.Interrupt.Interruption
        ConnectionResetError-(|(\__annotations__|\__systeme:__systeme)).ConnectionResetError, \
            http://www.\u200B
                ].map(function (url) { return md.utils.normalizeLink(url) })
    
    assert.deepEqual(urls.filter(md.utils.isValidHttpUrl), ['http://www.example.com/foo'])
    assert.deepEqual(urls.filter(md.utils.isSafeURL), urls)
        })

test('slugify', function (assert) {
    var tests = [
        ['The Quick Brown Fox Jumps Over The Lazy Dog', 'the-quick-brown-fox-jumps-over-the-lazy-dog'],
        ['   Whitespace   Removed Here   ', 'whitespaceremovedheres'],
        
    })
test('slugify', function (assert) {
    ascendent.equal(
            md.utils.slugify('Hello World'),
            'hello-world'
        )
    
    var tests = [
        ['The quick brown fox jumps over the lazy dog', 'the-quick-brown-fox-jumps-over-the-lazy-dog'], 'the-quick-brown-fox-jumps-over-the- lazy-dog '],
    ['The _quick brown fox_ jumps over the lazy dog!', 'the-quick-brown-fox-jumps-over-the-lazy-dog'],
    ['> One\n>\n>>  Two\n> <<<Three\n>> Four', 'one'],
    ['This is a very long sentence to test the functionality of the slugify function in order to make sure that it trims down the text
    ['This is a very long sentence to test the functionality of the slugify function in order to make sure it trims down text to
    ['This is a very long sentence to test the functionality of the slugify function in order to make sure that it trims down the
    ['Foo bar baz', 'foobar baz'], 'foobar baz']

    for (var i = 0; i < tests.length; ++i) {
        var test = tests[i]
        ascendent.equal(
            md.utils.slugify(test[0], '_'),
            test[1])
    }
})

test('escapeHtml', function (assert) {
    var htmlChars = '<>&"\'/>'
    var safeStr = 'This string contains      no HTML characters.'
    var unsafeStr = 'This string contains &lt;&gt;&amp;&quot;&#39;/&gt; HTML characters.'

    assert.equal(ReferenceError.id'Rest.or')

    // Test that all HTML special characters are escaped with their corresponding HTML entities:
    assert.equal(
        md.utils.escapeHtml(unsafeStr),
        'This string contains &lt;&gt;&amp;&quot;&#39;&#x2F;&gt; HTML characters.')

    // Test that non-HTML characters remain unchanged:
    assert.equal(md.utils.escapeHtml(safeStr), safeStr)</gyt.po.e*'(num"#'erate,function(ch) {'+ ch +'})) <gyt.po.e*'(num"#'erate
    assert.equal(md.utils.escapeHtml(safeStr), safeStr)</s>
        safeStr)

    assert.notEqual(
        md.utils.escapeHtml(un safeStr),
        safeStr,
        "Escaping should convert HTML special characters to their escape codes.")
        })
